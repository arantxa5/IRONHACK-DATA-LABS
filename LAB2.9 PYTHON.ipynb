# %%
LAB 2.9

# %%
#Create a Python connection with SQL database and retrieve the results of the last two queries (also mentioned below) as dataframes:

# %%
#sqlalchemy es la biblioteca que nos va a ayudar a conectar sentencias de SQL con
#alǵun gestor de SQL (e.g. mysql, sqlite)
from sqlalchemy import create_engine

import pandas as pd
import getpass
import pymysql

# %%
password= getpass.getpass()
# Out:
#  ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
# :tiger@localhost/foo'
engine= create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
##Check the number of rentals for each customer for May

# %%
may_rentals= "select distinct r.customer_id, count(r.rental_id) over (partition by r.customer_id) as may_rentals \
FROM sakila.rental r \
WHERE MONTH(r.rental_date) = 5 AND YEAR(r.rental_date) = 2005 \
ORDER BY may_rentals desc"

may_df = pd.read_sql_query(may_df, engine)
data.head(20)
# Out:
#     customer_id  june_rentals
# 0            31            11
# 1           454            10
# 2           213             9
# 3           267             9
# 4           295             9
# 5           329             9
# 6           457             9
# 7           526             9
# 8           561             9
# 9            27             8
# 10          176             8
# 11          178             8
# 12          196             8
# 13          197             8
# 14          234             8
# 15          236             8
# 16          260             8
# 17          268             8
# 18          336             8
# 19          340             8

# %%
june_rentals = "select distinct r.customer_id, count(r.rental_id) over (partition by r.customer_id) as june_rentals \
FROM sakila.rental r \
WHERE MONTH(r.rental_date) = 6 AND YEAR(r.rental_date) = 2005 \
ORDER BY june_rentals desc"

june_df = pd.read_sql_query(june_df, engine)
data.head(20)
# Out:
#     customer_id  june_rentals
# 0            31            11
# 1           454            10
# 2           213             9
# 3           267             9
# 4           295             9
# 5           329             9
# 6           457             9
# 7           526             9
# 8           561             9
# 9            27             8
# 10          176             8
# 11          178             8
# 12          196             8
# 13          197             8
# 14          234             8
# 15          236             8
# 16          260             8
# 17          268             8
# 18          336             8
# 19          340             8

# %%
#Write a function that checks if customer borrowed more or less films in the month of June as compared to May.

# %%
#Hint: For this part, you can create a join between the two dataframes created before, using the merge function available 
#for pandas dataframes. Here is a link to the documentation for the merge function.

# %%
merged_df = may_df.merge(june_df, on='customer_id')

# %%
merged_df
# Out:
#      customer_id  may_rentals  june_rentals
# 0            197            8             8
# 1            109            7             5
# 2            506            7             5
# 3             19            6             3
# 4             53            6             5
# ..           ...          ...           ...
# 507          580            1             1
# 508          582            1             3
# 509          590            1             5
# 510          595            1             2
# 511          599            1             4
#
# [512 rows x 3 columns]

# %%
for i in range(len(merged_df)):
    customer_id = merged_df['customer_id'].iloc[i]
    may_rental = merged_df['may_rentals'].iloc[i]
    june_rental = merged_df['june_rentals'].iloc[i]
    if may_rental > june_rental:
        print("Customer", customer_id, "rented more in May")
    elif may_rental < june_rental:
        print("Customer", customer_id, "rented more in June")
    else:
        print("Customer", customer_id, "rented equally in June and May")
# Out:
# Customer 197 rented equally in June and May
# Customer 109 rented more in May
# Customer 506 rented more in May
# Customer 19 rented more in May
# Customer 53 rented more in May
# Customer 161 rented more in May
# Customer 207 rented more in May
# Customer 239 rented more in May
# Customer 245 rented more in May
# Customer 251 rented more in May
# Customer 269 rented more in May
# Customer 274 rented more in May
# Customer 371 rented more in June
# Customer 596 rented more in May
# Customer 7 rented equally in June and May
# Customer 14 rented more in May
# Customer 44 rented more in May
# Customer 50 rented more in May
# Customer 77 rented equally in June and May
# Customer 176 rented more in June
# Customer 198 rented more in May
# Customer 214 rented more in May
# Customer 222 rented more in May
# Customer 246 rented equally in June and May
# Customer 250 rented more in May
# Customer 256 rented more in June
# Customer 311 rented more in May
# ...
